# %% [markdown]
# <a href="https://colab.research.google.com/github/khalidpark/Projects/blob/main/10minutes_pandas/10minutes_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
